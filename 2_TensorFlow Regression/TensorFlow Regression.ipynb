# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# In C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# ...

# %%
df=pd.read_csv('DATA/kc_house_data.csv')

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     21597 non-null  int64
#  9   view           21597 non-null  int64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  int64
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   21597 non-null  int64
#  16  zipcode        21597 non-null  int64
# ...

# %%
df.isnull().sum()
#no missing data
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007547      0.234292      3.409825
# ...

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['price'])
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.countplot(df['bedrooms'])
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='bedrooms', ylabel='count'>

# %%
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
sns.scatterplot(x='price',y='sqft_living',data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='sqft_living'>

# %%
sns.boxplot(x='bedrooms',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='long',data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='long'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='lat',data=df)
#some latitude and longitude are hotspots for the expensive houses
# Out:
# <AxesSubplot:xlabel='price', ylabel='lat'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',data=df)
#looks like the map of the king county
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',data=df,hue='price',cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
#we are not getting the quite the color gradient as we have expected. That is because of those extremely expensive outliers
#let's try to clean the above map a little bit by dropping some of the outliers.
df.sort_values('price',ascending=False).head(20)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
len(df)*0.01
#we will drop 1 percent information i.e the most expensive 1 percent houses. (outlier houses)
# Out:
# 215.97

# %%
non_top_1_perc=df.sort_values('price',ascending=False).iloc[216:]
#grabbing everything from index 216 uptill end. We are dropping 1 percent information.

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',data=non_top_1_perc,hue='price',palette='RdYlGn',alpha=0.2)
#this is a much better distribution scatter plot map
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
sns.boxplot(x='waterfront',y='price',data=df)
#if you are on waterfront the house is likely to be more expensive
# Out:
# <AxesSubplot:xlabel='waterfront', ylabel='price'>

# %%
#now let's start feature engineering process also getting rid of features that are not going to be useful to us
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df=df.drop('id',axis=1)

# %%
df['date']
# Out:
# 0        10/13/2014
# 1         12/9/2014
# 2         2/25/2015
# 3         12/9/2014
# 4         2/18/2015
#             ...
# 21592     5/21/2014
# 21593     2/23/2015
# 21594     6/23/2014
# 21595     1/16/2015
# 21596    10/15/2014
# Name: date, Length: 21597, dtype: object

# %%
#this date column looks like a string. We can convert it to datetime object
df['date']=pd.to_datetime(df['date'])

# %%
df['date']    #we can now perform feature engineering of it
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %%
#we can extract month and year of this.
df['year']=df['date'].apply(lambda date:date.year)
df['month']=df['date'].apply(lambda date:date.month)

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='month',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='price'>

# %%
df.groupby('month').mean()['price']
# Out:
# month
# 1     525963.251534
# 2     508520.051323
# 3     544057.683200
# 4     562215.615074
# 5     550849.746893
# 6     557534.318182
# 7     544892.161013
# 8     536655.212481
# 9     529723.517787
# 10    539439.447228
# 11    522359.903478
# 12    524799.902041
# Name: price, dtype: float64

# %%
df.groupby('year').mean()['price']
# Out:
# year
# 2014    539350.911777
# 2015    542279.005878
# Name: price, dtype: float64

# %%
df=df.drop('date',axis=1)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  ...  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7  ...              0      1955             0
# 1     0          3      7  ...            400      1951          1991
# 2     0          3      6  ...              0      1933             0
# 3     0          5      7  ...            910      1965             0
# 4     0          3      8  ...              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  year  month
# ...

# %%
df['zipcode'].value_counts()
# Out:
# 98103    602
# 98038    589
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    104
# 98010    100
# 98024     80
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
#there are 70 categories of the zipcode and getting dummies for 70 variables is probably too much, so we drop it
df=df.drop('zipcode',axis=1)

# %%
df['yr_renovated'].value_counts()
#categorize them to renovated or not renovated. 0 here means not renovated. while we can convert all to 1 meaning renovated
#we also keep this feature as it is, because we say that the recently the house got renovated the more price it has
# Out:
# 0       20683
# 2014       91
# 2013       37
# 2003       36
# 2007       35
#         ...
# 1948        1
# 1954        1
# 1951        1
# 1944        1
# 1959        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df['sqft_basement'].value_counts()
#we also keep this feature as it is, because it is intuitve that a house having a basement will have higher value. 
#so we keep this feature as it is.
# Out:
# 0       13110
# 600       221
# 700       218
# 500       214
# 800       206
#         ...
# 65          1
# 1248        1
# 172         1
# 1920        1
# 1135        1
# Name: sqft_basement, Length: 306, dtype: int64

# %%
#feature engineering and EDA is an extremely important part for any data science and machine learning project

# %%
X=df.drop('price',axis=1).values
y=df['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
#now we perform scaling.
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X_train.shape
#we have 19 incoming features. So that is a good range to have 19 neurons in our layer
# Out:
# (15117, 19)

# %%
model=Sequential()
#we will explore later on, is to see how we can use early stoppings in order to try to choose the correct number to train
#for, but also to choose correct number of layers to train for.

model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))

model.add(Dense(1))

model.compile(optimizer='adam',loss='mse')

# %%
model.fit(x=X_train,y=y_train,validation_data=(X_test,y_test),batch_size=128,epochs=400)
#validation_data: Data on which to evaluate the loss and any model metrics at the end of each epoch.The model will not be 
#trained on this data.
# Out:
# Train on 15117 samples, validate on 6480 samples
# Epoch 1/400
# 15117/15117 [==============================] - 2s 126us/sample - loss: 430240642458.1555 - val_loss: 418915445701.8469
# Epoch 2/400
# 15117/15117 [==============================] - 1s 42us/sample - loss: 429064556356.2294 - val_loss: 414723876818.4889
# Epoch 3/400
# 15117/15117 [==============================] - 1s 38us/sample - loss: 411514834152.5456 - val_loss: 374043587702.8346
# Epoch 4/400
# 15117/15117 [==============================] - 1s 42us/sample - loss: 324022301622.7749 - val_loss: 235102957133.1161
# Epoch 5/400
# 15117/15117 [==============================] - 1s 39us/sample - loss: 166185706146.6736 - val_loss: 106228667096.1778
# Epoch 6/400
# 15117/15117 [==============================] - 1s 43us/sample - loss: 101387169729.4098 - val_loss: 95009968987.6543
# Epoch 7/400
# 15117/15117 [==============================] - 1s 42us/sample - loss: 97339991910.5050 - val_loss: 93308159914.0346
# ...

# %%
#explore and evaluate our data
model.history.history
# Out:
# {'loss': [430240642458.15546,
#   429064556356.22943,
#   411514834152.5456,
#   324022301622.7749,
#   166185706146.67355,
#   101387169729.4098,
#   97339991910.50499,
#   95389879456.74301,
#   93302491717.87207,
#   91125894209.63843,
#   88861742882.49573,
#   86454827370.39995,
#   83972006514.98578,
#   81343280275.4663,
#   78607102413.97527,
#   75737839303.86188,
#   72788106508.44691,
#   69750558839.76132,
#   66769719889.92948,
#   63849146825.06423,
#   61110382335.949196,
#   58621680066.86618,
#   56504107965.95515,
#   54658969584.555664,
#   53189348961.306076,
#   52009711949.00152,
#   51004481239.30621,
#   50186659039.19772,
#   49529899315.6674,
#   48878892468.844345,
#   48298868554.86777,
#   47844188088.197395,
#   47367828043.29113,
#   46959911905.5855,
#   46573108106.20308,
#   46164213633.60032,
#   45828111846.42879,
#   45453951208.61335,
#   45127359954.17503,
#   44782770458.67196,
#   44487694269.21003,
#   44247995955.514984,
# ...

# %%
pd.DataFrame(model.history.history)
#loss on training and validation data
# Out:
#              loss      val_loss
# 0    4.302406e+11  4.189154e+11
# 1    4.290646e+11  4.147239e+11
# 2    4.115148e+11  3.740436e+11
# 3    3.240223e+11  2.351030e+11
# 4    1.661857e+11  1.062287e+11
# ..            ...           ...
# 395  2.958132e+10  2.720248e+10
# 396  2.959235e+10  2.721123e+10
# 397  2.960156e+10  2.718415e+10
# 398  2.955388e+10  2.712627e+10
# 399  2.956473e+10  2.712282e+10
#
# [400 rows x 2 columns]

# %%
#now we can directly compare loss and val_loss to see if we are overfitting to the training data on our model
losses=pd.DataFrame(model.history.history)
losses.plot()
#since the validation is going down upto 400 epochs and not increasing, that is an indicator that we could continue training
#without overfitting to our training data. If val_loss line begin to spike after some of the epoch, it means we are
#overfitting to the training data because then we have a much larger loss on the validation data.
#Further, we will talk abou early stoppings.
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score

# %%
predictions=model.predict(X_test)

# %%
mean_squared_error(y_test,predictions)
# Out:
# 27122821976.957657

# %%
mean_squared_error(y_test,predictions)**0.5
# Out:
# 164690.07856260697

# %%
mean_absolute_error(y_test,predictions)
#tells average absolute error across all the predictions
# Out:
# 102151.40942081405

# %%
df['price'].describe()
# Out:
# count    2.159700e+04
# mean     5.402966e+05
# std      3.673681e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
explained_variance_score(y_test,predictions)
#model explains around 80 percent of the variance. Which is merely ok!
# Out:
# 0.7955006714101572

# %%
plt.figure(figsize=(12,6))
plt.scatter(y_test,predictions)
plt.plot(y_test,y_test,'r')      #this line represents the perfect prediction line
#In the grapg it looks like we are being punished by the extremely expensive houses, the outliers. We are doing good on the
#houses between 0 and 2 miliion

# %%
#let's use our model to predict on brand new house
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
df.drop('price',axis=1).iloc[0]
#we try to predict the price of the very 1st house
# Out:
# bedrooms            3.0000
# bathrooms           1.0000
# sqft_living      1180.0000
# sqft_lot         5650.0000
# floors              1.0000
# waterfront          0.0000
# view                0.0000
# condition           3.0000
# grade               7.0000
# sqft_above       1180.0000
# sqft_basement       0.0000
# yr_built         1955.0000
# yr_renovated        0.0000
# lat                47.5112
# long             -122.2570
# sqft_living15    1340.0000
# sqft_lot15       5650.0000
# year             2014.0000
# month              10.0000
# Name: 0, dtype: float64

# %%
single_house=df.drop('price',axis=1).iloc[0]

# %%
single_house.values.reshape(-1,19)     #.values to convert into numpy array
#to add double brackets hence (-1,19)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-f847939520e0> in <module>
# ----> 1 single_house.values.reshape(-1,19)     #.values to convert into numpy array
#       2 #to add double brackets hence (-1,19)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
#we scale our data since our model is trained on scaled values
scaler.transform(single_house.values.reshape(-1,19))
# Out:
# array([[0.2       , 0.08      , 0.08376422, 0.00310751, 0.        ,
#         0.        , 0.        , 0.5       , 0.4       , 0.10785619,
#         0.        , 0.47826087, 0.        , 0.57149751, 0.21760797,
#         0.16193426, 0.00582059, 0.        , 0.81818182]])

# %%
single_house=scaler.transform(single_house.values.reshape(-1,19))

# %%
model.predict(single_house)
# Out:
# array([[278549.38]], dtype=float32)

# %%
df.head(1)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3        1.0         1180      5650     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
#
#        lat     long  sqft_living15  sqft_lot15  year  month
# 0  47.5112 -122.257           1340        5650  2014     10

# %%
#a possible approach is to drop top 1 percent outlier houses and retrain our model to see if that reduces our MSE
